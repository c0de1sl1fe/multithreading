# %%
import matplotlib.pyplot as plt

def readStats(path: str):
    x = []
    y = []
    with open(path, "r") as f:
        line = f.readline()
        while line: 
            tmp =[int(x) for x in line.split(" ")]
            print(tmp)
            x.append(tmp[0])
            y.append(tmp[1])
            line = f.readline()
    return (x,y)

x = []
y = []
x, y = readStats("D:\git\multithreading\stats_lab1.txt")
x.sort()
y.sort()
plt.plot(x, y, label='lab1')


x_2 = []
y_2 = []
x_2, y_2 = readStats("D:\git\multithreading\stats_lab2.txt")
x_2.sort()
y_2.sort()
plt.plot(x_2, y_2, label='lab2')




plt.title("Dependens of time on size")
plt.xlabel("Size")
plt.ylabel("Time")
plt.legend()
plt.show()
# Out:
# [48020, 27818]
# [500, 44]
# [720, 54]
# [980, 120]
# [1280, 158]
# [1620, 213]
# [2000, 241]
# [2420, 329]
# [2880, 412]
# [3380, 544]
# [3920, 660]
# [4500, 840]
# [5120, 994]
# [5780, 1146]
# [6480, 1395]
# [7220, 1586]
# [8000, 1915]
# [8820, 2138]
# [9680, 2561]
# [10580, 2830]
# [11520, 3197]
# [12500, 3641]
# [13520, 4236]
# [14580, 5098]
# [15680, 5111]
# [16820, 5664]
# [18000, 6295]
# [19220, 7096]
# [20480, 7606]
# [21780, 8518]
# [23120, 9278]
# [24500, 10230]
# [25920, 10778]
# [27380, 11714]
# [28880, 12765]
# [30420, 13655]
# [32000, 14807]
# [33620, 15999]
# [35280, 17534]
# [36980, 18595]
# [38720, 19738]
# [40500, 21118]
# [42320, 23016]
# [44180, 24207]
# [46080, 26044]
# [48020, 28022]
# [48020, 27663]
# [2000, 281]
# [2880, 466]
# [3920, 672]
# [5120, 965]
# [6480, 1396]
# [8000, 1926]
# [9680, 2475]
# [11520, 3274]
# [13520, 4281]
# [15680, 5161]
# [18000, 6322]
# [20480, 7620]
# [23120, 9328]
# [25920, 10921]
# [28880, 13241]
# [32000, 14821]
# [35280, 17558]
# ...
