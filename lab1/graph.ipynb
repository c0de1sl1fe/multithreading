# %%
import matplotlib.pyplot as plt

def readStats(path: str):
    x = []
    y = []
    with open(path, "r") as f:
        line = f.readline()
        while line: 
            tmp =[int(x) for x in line.split(" ")]
            print(tmp)
            x.append(tmp[0])
            y.append(tmp[1])
            line = f.readline()
    return (x,y)
x = []
y = []
x, y = readStats("D:\Git\multithreading\stats.txt")
x.sort()
y.sort()



plt.plot(x, y, color="blue")
plt.title("Dependens of time on size")
plt.xlabel("Size")
plt.ylabel("Time")
plt.show()
# Out:
# [15, 5]
# [20, 3]
# [20, 3]
# [150000, 187069]
# [150000, 186681]
# [150000, 180902]
# [150000, 180992]
# [150000, 184211]
# [150000, 181170]
# [150000, 181352]
# [150000, 180346]
# [150000, 186925]
# [150000, 189012]
# [2000, 233]
# [8000, 1889]
# [18000, 6183]
# [32000, 14706]
# [50000, 28783]
# [72000, 49979]
# [98000, 81516]
# [128000, 120450]
# [162000, 178351]
# [200000, 241765]
# [242000, 320676]
# [288000, 436191]
# [338000, 544307]
# [392000, 678647]
# [450000, 845467]
# [512000, 999231]
# [578000, 1204801]
# [648000, 1484354]
# [722000, 1694009]
# [800000, 2129480]
# [882000, 2372168]
# [968000, 2758559]
# [1058000, 3117315]
# [1152000, 3555515]
# [1250000, 4169723]
# [1352000, 4563021]
# [1458000, 5084859]
# [1568000, 5771939]
# [1682000, 6442749]
# [1800000, 7750716]
# [1922000, 8084102]
# [2048000, 9109030]
# [2178000, 10017954]
# [2312000, 11315998]
# [2450000, 12538624]
# [2592000, 14677698]
# [2738000, 15754843]
# [2888000, 18406992]
# [3042000, 19438788]
# [3200000, 23995153]
# [3362000, 22796887]
# [3528000, 28670653]
# [3698000, 29028263]
# [3872000, 33004828]
# [4050000, 35481887]
# [500, 42]
# [720, 71]
# [980, 120]
# [1280, 128]
# [1620, 178]
# [2000, 233]
# [2420, 320]
# [2880, 414]
# [3380, 525]
# [3920, 650]
# [4500, 780]
# [5120, 950]
# [5780, 1136]
# [6480, 1348]
# [7220, 1586]
# [8000, 1869]
# [8820, 2123]
# [9680, 2507]
# [10580, 2868]
# [11520, 3217]
# [12500, 3604]
# [13520, 4215]
# [14580, 4663]
# [15680, 5162]
# [16820, 5629]
# [18000, 6204]
# [19220, 7096]
# [20480, 7580]
# [21780, 8228]
# [23120, 9383]
# [24500, 10054]
# [25920, 10666]
# [27380, 11666]
# [28880, 12831]
# [30420, 13813]
# [32000, 14707]
# [33620, 15893]
# [35280, 17321]
# [36980, 18526]
# [38720, 19535]
# [40500, 20947]
# [42320, 22350]
# [44180, 23779]
# [46080, 26053]
# [48020, 27595]
# <>:17: SyntaxWarning: invalid escape sequence '\G'
# <>:17: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\every\AppData\Local\Temp\ipykernel_17952\160745353.py:17: SyntaxWarning: invalid escape sequence '\G'
#   x, y = readStats("D:\Git\multithreading\stats.txt")
